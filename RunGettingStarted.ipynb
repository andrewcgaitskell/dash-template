# %%
import papermill as pm

pm.execute_notebook(
   'getting_started.ipynb',
   'output.ipynb',
    parameters = dict(port=8052)
)
# Out:
# Executing:   0%|          | 0/32 [00:00<?, ?cell/s]
# No handler found for comm target 'jupyter_dash'
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2022-01-12T11:58:40.244239',
#      'end_time': '2022-01-12T11:58:40.265850',
#      'duration': 0.021611,
#      'status': 'completed'}},
#    'source': '# JupyterDash\nThe `jupyter-dash` package makes it easy to develop Plotly Dash apps from the Jupyter Notebook and JupyterLab.\n\nJust replace the standard `dash.Dash` class with the `jupyter_dash.JupyterDash` subclass.',
#    'id': '9f918300'},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2022-01-12T11:58:40.287542',
#      'end_time': '2022-01-12T11:58:40.323086',
#      'duration': 0.035544,
#      'status': 'completed'},
# ...
